# %% [markdown]
# ### Elvis Selimaj Mars Challenge

# %%
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import pandas as pd
#import nbconvert

# %%
#URL to be scraped
url = 'https://mars.nasa.gov/news/'
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# %%
#Review html format
#print(soup.prettify())

# %%
#Narrow the div and class to see how best to loop through
results = soup.find_all('div', class_="content_title")
results
# Out:
# [<div class="content_title">
#  <a href="/news/8508/nasa-invites-students-to-name-mars-2020-rover/">
#  NASA Invites Students to Name Mars 2020 Rover
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8442/nasas-curiosity-mars-rover-finds-a-clay-cache/">
#  NASA's Curiosity Mars Rover Finds a Clay Cache
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8436/why-this-martian-full-moon-looks-like-candy/">
#  Why This Martian Full Moon Looks Like Candy
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
#  NASA Garners 7 Webby Award Nominations
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8413/nasas-opportunity-rover-mission-on-mars-comes-to-end/">
#  NASA's Opportunity Rover Mission on Mars Comes to End
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8402/nasas-insight-places-first-instrument-on-mars/">
#  NASA's InSight Places First Instrument on Mars
#  </a>
#  </div>]

# %%
# A blank list to hold the headlines
news_titles = []
# Loop over div elements
for result in results:
    # Identify the anchor...
    if (result.a):
        # And the anchor has non-blank text...
        if (result.a.text):
            # Append thext to the list
            news_titles.append(result)
news_titles
# Out:
# [<div class="content_title">
#  <a href="/news/8508/nasa-invites-students-to-name-mars-2020-rover/">
#  NASA Invites Students to Name Mars 2020 Rover
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8442/nasas-curiosity-mars-rover-finds-a-clay-cache/">
#  NASA's Curiosity Mars Rover Finds a Clay Cache
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8436/why-this-martian-full-moon-looks-like-candy/">
#  Why This Martian Full Moon Looks Like Candy
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
#  NASA Garners 7 Webby Award Nominations
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8413/nasas-opportunity-rover-mission-on-mars-comes-to-end/">
#  NASA's Opportunity Rover Mission on Mars Comes to End
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8402/nasas-insight-places-first-instrument-on-mars/">
#  NASA's InSight Places First Instrument on Mars
#  </a>
#  </div>]

# %%
finalnewstitles = []
# Print only the headlines
for x in range(6):
    var=news_titles[x].text
    newvar = var.strip('\n\n')
    finalnewstitles.append(newvar)
finalnewstitles
# Out:
# ['NASA Invites Students to Name Mars 2020 Rover',
#  "NASA's Curiosity Mars Rover Finds a Clay Cache",
#  'Why This Martian Full Moon Looks Like Candy',
#  'NASA Garners 7 Webby Award Nominations',
#  "NASA's Opportunity Rover Mission on Mars Comes to End",
#  "NASA's InSight Places First Instrument on Mars"]

# %%
#Find classification for description paragraph below title
presults = soup.find_all('div', class_="rollover_description_inner")
presults
# Out:
# [<div class="rollover_description_inner">
#  Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.
#  </div>, <div class="rollover_description_inner">
#  The rover recently drilled two samples, and both showed the highest levels of clay ever found during the mission.
#  </div>, <div class="rollover_description_inner">
#  For the first time, NASA's Mars Odyssey orbiter has caught the Martian moon Phobos during a full moon phase. Each color in this new image represents a temperature range detected by Odyssey's infrared camera.
#  </div>, <div class="rollover_description_inner">
#  Nominees include four JPL projects: the solar system and climate websites, InSight social media, and a 360-degree Earth video. Public voting closes April 18, 2019.
#  </div>, <div class="rollover_description_inner">
#  NASA's Opportunity Mars rover mission is complete after 15 years on Mars. Opportunity's record-breaking exploration laid the groundwork for future missions to the Red Planet.
#  </div>, <div class="rollover_description_inner">
#  In deploying its first instrument onto the surface of Mars, the lander completes a major mission milestone.
#  </div>]

# %%
news_p = []
# Loop through the div results to pull out just the text
for x in range(6):
    var=presults[x].text
    newvar = var.strip('\n\n')
    news_p.append(newvar)
news_p
# Out:
# ["Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover.",
#  'The rover recently drilled two samples, and both showed the highest levels of clay ever found during the mission.',
#  "For the first time, NASA's Mars Odyssey orbiter has caught the Martian moon Phobos during a full moon phase. Each color in this new image represents a temperature range detected by Odyssey's infrared camera.",
#  'Nominees include four JPL projects: the solar system and climate websites, InSight social media, and a 360-degree Earth video. Public voting closes April 18, 2019.',
#  "NASA's Opportunity Mars rover mission is complete after 15 years on Mars. Opportunity's record-breaking exploration laid the groundwork for future missions to the Red Planet.",
#  'In deploying its first instrument onto the surface of Mars, the lander completes a major mission milestone.']

# %%
### JPL Mars Space Images - Featured Image

# %%
url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
#executable_path = {'executable_path': 'chromedriver.exe'}
#browser = Browser('chrome', **executable_path, headless=False)
#browser.visit(url)
response = requests.get(url)
soup = bs(response.text, 'html.parser')

# %%
#Review html format
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]> <html class="no-js ie ie9" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="no-js ie ie8" lang="en"> <![endif]-->
# <html>
#  <!-- START HEADER: "DEFAULT" -->
#  <!-- Google Tag Manager -->
#  <script>
#   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
# {'gtm.start': new Date().getTime(),event:'gtm.js'}
# );var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NLDQZ25');
#  </script>
#  <!-- End Google Tag Manager -->
#  <head>
#   <meta charset="utf-8"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <title>
#    Space Images
#   </title>
#   <link href="/assets/stylesheets/manifest.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="/assets/stylesheets/print.css" media="print" rel="stylesheet" type="text/css"/>
#   <script src="/assets/javascripts/public_manifest.js" type="text/javascript">
#   </script>
#   <script src="/assets/javascripts/vendor/jquery.fancybox.js" type="text/javascript">
#   </script>
#   <script src="/assets/javascripts/vendor/jquery.fancybox-thumbs.js" type="text/javascript">
#   </script>
#  </head>
#  <body class="dark_background logged_out mobile_menu" id="images">
#   <!--[if lt IE 9]>
#       <div class='browsehappy' style='font-size: 30px; color: white; position:absolute; top: 0; margin: 0; height: 3000px; width: 100%; background: #000; z-index: 10000; padding: 5%;'>
#         You are using an
#         <strong>outdated</strong>
#         browser. Please
#         <a href='http://browsehappy.com/'>click here</a>
#         to upgrade or change your browser.
#       </div>
#     <![endif]-->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NLDQZ25" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div id="main_container">
#    <div id="site_body">
#     <div class="site_header_area">
#      <header class="site_header">
#       <div class="brand_area">
#        <div class="brand1">
#         <a class="nasa_logo" href="http://www.nasa.gov" title="NASA">
#          NASA
#         </a>
#        </div>
#        <div class="brand2">
#         <div class="jpl_logo">
#          <a href="//www.jpl.nasa.gov/" id="jpl_logo" title="Jet Propulsion Laboratory">
#           Jet Propulsion Laboratory
#          </a>
#         </div>
#         <div class="caltech_logo">
#          <a href="http://www.caltech.edu/" id="caltech_logo" target="_blank" title="California Institute of Technology">
#           California Institute of Technology
#          </a>
#         </div>
#        </div>
#        <img alt="" class="print_only print_logo" src="/assets/images/logo_nasa_trio_black@2x.png"/>
#       </div>
#       <a class="visuallyhidden focusable" href="#main">
#        Skip Navigation
#       </a>
#       <div class="nav_area">
#        <a class="menu_button" href="javascript:void(0);" id="menu_button" title="menu button">
#         <span class="menu_icon">
#          menu and search
#         </span>
#        </a>
#       </div>
#      </header>
#     </div>
#     <div class="main_nav_overlay">
#      <div class="modal_menu">
#       <header class="site_header clearfix">
#        <div class="brand_area">
#         <div class="brand1">
#          <a class="nasa_logo" href="http://www.nasa.gov" title="">
#          </a>
#         </div>
#         <div class="brand2">
#          <div class="jpl_logo">
#           <a class="" href="" id="jpl_logo" title="">
#            Jet Propulsion Laboratory
#           </a>
#          </div>
#          <div class="caltech_logo">
#           <a class="" href="" id="caltech_logo" title="">
#            California Institute of Technology
#           </a>
#          </div>
#         </div>
#         <img alt="" class="print_only print_logo" src="/assets/images/logo_nasa_trio_black@2x.png"/>
#        </div>
#        <a class="modal_close" id="modal_close" title="close menu">
#         close menu
#        </a>
#        <div class="nav_area">
#         <a class="menu_button modal_close" href="javascript:void(0);" id="menu_button" title="menu icon">
#          <span class="menu_icon">
#           menu
#          </span>
#         </a>
#        </div>
#       </header>
#       <section class="navigation_area">
#        <div class="grid_layout">
#         <div class="directory">
#          <form action="/search.php" class="overlay_search top_search">
#           <input class="search_field" name="q" onblur="this.placeholder = 'search'" onfocus="this.placeholder = ''" placeholder="search" type="text" value=""/>
#           <input class="search_submit" type="submit" value=""/>
#          </form>
#          <div class="nav_item">
#           <div class="arrow_box">
#            <span class="arrow_down">
#            </span>
#           </div>
#           <h3 class="nav_title">
#            <a href="/about">
#             about JPL
#            </a>
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/about">
#              about JPL
#             </a>
#            </li>
#            <li>
#             <a href="/about/exec.php">
#              executive council
#             </a>
#            </li>
#            <li>
#             <a href="/about/history.php">
#              history
#             </a>
#            </li>
#            <li>
#             <a href="/about/reports.php">
#              annual reports
#             </a>
#            </li>
#            <li>
#             <a href="/contact_JPL.php">
#              contact us
#             </a>
#            </li>
#            <li>
#             <a href="/opportunities/">
#              opportunities
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="gradient_line">
#          </div>
#          <div class="nav_item">
#           <div class="arrow_box">
#            <span class="arrow_down">
#            </span>
#           </div>
#           <h3 class="nav_title">
#            <a href="/events">
#             public events
#            </a>
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/events">
#              overview
#             </a>
#            </li>
#            <li>
#             <a href="/events/tours/views">
#              tours
#             </a>
#            </li>
#            <li>
#             <a href="/events/lectures.php">
#              lecture series
#             </a>
#            </li>
#            <li>
#             <a href="/events/speakers-bureau.php">
#              speakers bureau
#             </a>
#            </li>
#            <li>
#             <a href="/events/team-competitions.php">
#              team competitions
#             </a>
#            </li>
#            <li>
#             <a href="/events/special-events.php">
#              special events
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="gradient_line">
#          </div>
#          <div class="nav_item">
#           <div class="arrow_box">
#            <span class="arrow_down">
#            </span>
#           </div>
#           <h3 class="nav_title">
#            <a href="/edu/">
#             education
#            </a>
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/edu/intern/">
#              Intern
#             </a>
#            </li>
#            <li>
#             <a href="/edu/learn/">
#              Learn
#             </a>
#            </li>
#            <li>
#             <a href="/edu/teach/">
#              Teach
#             </a>
#            </li>
#            <li>
#             <a href="/edu/news/">
#              News
#             </a>
#            </li>
#            <li>
#             <a href="/edu/events/">
#              Events
#             </a>
#            </li>
#            <li>
#             <a href="https://spaceplace.nasa.gov/menu/play/">
#              Games
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="gradient_line">
#          </div>
#          <div class="nav_item">
#           <div class="arrow_box">
#            <span class="arrow_down">
#            </span>
#           </div>
#           <h3 class="nav_title">
#            <a href="/news">
#             news
#            </a>
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/news">
#              latest news
#             </a>
#            </li>
#            <li>
#             <a href="/news/presskits.php">
#              press kits
#             </a>
#            </li>
#            <li>
#             <a href="/news/factsheets.php">
#              fact sheets
#             </a>
#            </li>
#            <li>
#             <a href="/news/mediainformation.php">
#              media information
#             </a>
#            </li>
#            <li>
#             <a href="http://blogs.jpl.nasa.gov">
#              blog
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="gradient_line">
#          </div>
#          <div class="nav_item">
#           <div class="arrow_box">
#            <span class="arrow_down">
#            </span>
#           </div>
#           <h3 class="nav_title">
#            <a href="/missions/">
#             missions
#            </a>
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/missions/?type=current">
#              current
#             </a>
#            </li>
#            <li>
#             <a href="/missions/?type=past">
#              past
#             </a>
#            </li>
#            <li>
#             <a href="/missions/?type=future">
#              future
#             </a>
#            </li>
#            <li>
#             <a href="/missions/?type=proposed">
#              proposed
#             </a>
#            </li>
#            <li>
#             <a href="/missions">
#              all
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="gradient_line">
#          </div>
#          <div class="nav_item">
#           <div class="arrow_box">
#            <span class="arrow_down">
#            </span>
#           </div>
#           <h3 class="nav_title">
#            <a href="/spaceimages">
#             galleries
#            </a>
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/spaceimages">
#              images
#             </a>
#            </li>
#            <li>
#             <a href="/videos">
#              videos
#             </a>
#            </li>
#            <li>
#             <a href="/infographics">
#              infographics
#             </a>
#            </li>
#            <li>
#             <a href="/multimedia/audio.php">
#              audio
#             </a>
#            </li>
#            <li>
#             <a href="/apps/">
#              apps
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="gradient_line">
#          </div>
#          <div class="nav_item centered">
#           <h3 class="nav_title">
#            <a href="/social">
#             Follow JPL
#            </a>
#           </h3>
#           <div class="social_icons">
#            <!-- AddThis Button BEGIN -->
#            <div class="addthis_toolbox addthis_default_style addthis_32x32_style">
#             <a addthis:userid="NASAJPL" class="addthis_button_facebook_follow icon">
#             </a>
#             <a addthis:userid="NASAJPL" class="addthis_button_twitter_follow icon">
#             </a>
#             <a addthis:userid="JPLnews" class="addthis_button_youtube_follow icon">
#             </a>
#             <a addthis:userid="nasajpl" class="addthis_button_instagram_follow icon">
#             </a>
#             <a class="icon all_icon" href="/social">
#              <span>
#               All
#              </span>
#             </a>
#            </div>
#           </div>
#          </div>
#          <form action="/search.php" class="overlay_search">
#           <input class="search_field" name="q" onblur="this.placeholder = 'search'" onfocus="this.placeholder = ''" placeholder="search" type="text" value=""/>
#           <input class="search_submit" type="submit" value=""/>
#          </form>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <a name="main">
#     </a>
#     <div id="page">
#      <!-- END HEADER: "DEFAULT" -->
#      <!-- START CONTENT -->
#      <section class="centered_text clearfix main_feature primary_media_feature single">
#       <div class="carousel_container">
#        <div class="carousel_items">
#         <article alt="Titan's Northern Lakes: Salt Flats?" class="carousel_item" style="background-image: url('/spaceimages/images/wallpaper/PIA17470-1920x1200.jpg');">
#          <div class="default floating_text_area ms-layer">
#           <h2 class="category_title">
#           </h2>
#           <h2 class="brand_title">
#            FEATURED IMAGE
#           </h2>
#           <h1 class="media_feature_title">
#            Titan's Northern Lakes: Salt Flats?
#           </h1>
#           <div class="description">
#           </div>
#           <footer>
#            <a class="button fancybox" data-description="NASA's Cassini spacecraft reveals the differences in the composition of surface materials around hydrocarbon lakes at Titan." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA17470_ip.jpg" data-link="/spaceimages/details.php?id=PIA17470" data-title="Titan's Northern Lakes: Salt Flats?" id="full_image">
#             FULL IMAGE
#            </a>
#           </footer>
#          </div>
#          <div class="gradient_container_top">
#          </div>
#          <div class="gradient_container_bottom">
#          </div>
#         </article>
#        </div>
#       </div>
#      </section>
#      <section class="filter_bar module">
#       <div class="grid_layout">
#        <header>
#         <h2 class="module_title_small">
#          Mars Images
#         </h2>
#         <div class="arrow_box">
#          <span class="arrow_down">
#          </span>
#         </div>
#        </header>
#        <form action="#submit" class="section_search">
#         <div class="search_binder">
#          <input class="search_field" name="search" onblur="this.placeholder = 'search'" onfocus="this.placeholder = ''" placeholder="search" type="text" value=""/>
#          <input class="search_submit" type="submit" value=""/>
#         </div>
#         <select name="category" onchange="this.form.submit()">
#          <option value="">
#           All
#          </option>
#          <option value="featured">
#           Featured
#          </option>
#          <option value="Asteroids and Comets">
#           Asteroids and Comets
#          </option>
#          <option value="Dwarf Planet">
#           Dwarf Planet
#          </option>
#          <option value="Earth">
#           Earth
#          </option>
#          <option value="Ida">
#           Ida
#          </option>
#          <option value="Jupiter">
#           Jupiter
#          </option>
#          <option selected="selected" value="Mars">
#           Mars
#          </option>
#          <option value="Mercury">
#           Mercury
#          </option>
#          <option value="Neptune">
#           Neptune
#          </option>
#          <option value="pnf">
#           pnf
#          </option>
#          <option value="Saturn">
#           Saturn
#          </option>
#          <option value="Spacecraft and Technology">
#           Spacecraft and Technology
#          </option>
#          <option value="Spacecraft and Telescope">
#           Spacecraft and Telescope
#          </option>
#          <option value="Sun">
#           Sun
#          </option>
#          <option value="tech">
#           tech
#          </option>
#          <option value="Universe">
#           Universe
#          </option>
#          <option value="Uranus">
#           Uranus
#          </option>
#          <option value="Venus">
#           Venus
#          </option>
#         </select>
#        </form>
#       </div>
#      </section>
#      <div class="filter_bar_spanner">
#      </div>
#      <script src="/assets/javascripts/grid_list_page.js" type="text/javascript">
#      </script>
#      <script>
#       function build_image_item(data){
#             var html = "<li class=\"slide\">";
# 			html += "<a class='fancybox' data-fancybox-group='images' data-fancybox-href='" + data.images.full.src +"' data-title='" + data.title + "' data-description='" + data.tease + "' data-link='" + data.link + "' data-thumbnail='" + data.images.thumb.src + "'>";
#             html +=       "<div class=\"image_and_description_container\">";
#             html +=         "<div class=\"rollover_description\" style=\"word-wrap: break-word;\">";
#             html +=		      "<h3 class=\"release_date\">"+data.date+"<\/h3>";
# 		    html +=		      "<div class=\"item_tease_overlay\">"+data.title+"<\/div>";
#             html +=           "<div class=\"overlay_arrow\">";
#             html +=             "<img alt=\"more arrow\" src=\"/assets/images/overlay-arrow.png\">";
#             html +=           "<\/div>";
#             html +=         "<\/div>";
#             html +=         "<div class=\"img\"><img alt=\""+data.images.thumb.alt+"\" class=\"thumb\" src=\""+data.images.thumb.src+"\"><\/div>";
#             html +=         "<div class=\"list_text_content\">";
#             html +=		      "<div class=\"article_teaser_body\">"+data.date+"<\/div>";
#             html +=           "<div class=\"content_title\">";
#             html +=             data.title
#             html +=           "<\/div>";
#             html +=           "<div class=\"article_teaser_body\">"
#             html +=             data.tease
#             html +=           "<\/div>"
#             html +=         "<\/div>"
#             html +=       "<\/div>"
#             html +=  "<\/a>";
#             html +=  "<\/li>";
#             return html;
#         };
# 		$(document).ready(function(){
# 			$('ul.articles').more_items({"url": "/assets/json/getMore.php?images=true&" + $.param(mb_utils._getQueryParams()), "build_item_fn": build_image_item})
# 		});
#      </script>
#      <section class="grid_gallery module grid_view">
#       <div class="grid_layout">
#        <header>
#         <h2 class="module_title">
#          Mars Images
#         </h2>
#         <div class="view_selectors">
#          <a class="nav_item ir list_icon">
#           list view
#          </a>
#          <a class="nav_item ir grid_icon">
#           grid view
#          </a>
#         </div>
#        </header>
#        <ul class="articles">
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of an unnamed crater in Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23599_hires.jpg" data-link="/spaceimages/details.php?id=PIA23599" data-thumbnail="/spaceimages/images/wallpaper/PIA23599-640x350.jpg" data-title="Terra Sabaea Crater - False Color">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 19, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Terra Sabaea Crater - False Color
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Terra Sabaea Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23599-640x350.jpg" title="Terra Sabaea Crater - False Color"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 19, 2019
#             </div>
#             <div class="content_title">
#              Terra Sabaea Crater - False Color
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of the floor of an unnamed crater in Terra Sabaea.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the inner rim, central peak ring and floor of Sagan Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23598_hires.jpg" data-link="/spaceimages/details.php?id=PIA23598" data-thumbnail="/spaceimages/images/wallpaper/PIA23598-640x350.jpg" data-title="Sagan Crater - False Color">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 18, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Sagan Crater - False Color
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Sagan Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23598-640x350.jpg" title="Sagan Crater - False Color"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 18, 2019
#             </div>
#             <div class="content_title">
#              Sagan Crater - False Color
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of the inner rim, central peak ring and floor of Sagan Crater.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This map of the Red Planet shows Jezero Crater, where NASAs Mars 2020 rover is scheduled to land in February 2021." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23518_hires.jpg" data-link="/spaceimages/details.php?id=PIA23518" data-thumbnail="/spaceimages/images/wallpaper/PIA23518-640x350.jpg" data-title="Map of NASA" landing="" mars="" s="" sites'="">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 17, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Map of NASA's Mars Landing Sites
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Map of NASA" class="thumb" landing="" mars="" s="" sites'="" src="/spaceimages/images/wallpaper/PIA23518-640x350.jpg" title="Map of NASA"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 17, 2019
#             </div>
#             <div class="content_title">
#              Map of NASA's Mars Landing Sites
#             </div>
#             <div class="article_teaser_body">
#              This map of the Red Planet shows Jezero Crater, where NASAs Mars 2020 rover is scheduled to land in February 2021.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the interior of Crommelin Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23597_hires.jpg" data-link="/spaceimages/details.php?id=PIA23597" data-thumbnail="/spaceimages/images/wallpaper/PIA23597-640x350.jpg" data-title="Crommelin Crater - False Color">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 17, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Crommelin Crater - False Color
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Crommelin Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23597-640x350.jpg" title="Crommelin Crater - False Color"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 17, 2019
#             </div>
#             <div class="content_title">
#              Crommelin Crater - False Color
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of the interior of Crommelin Crater.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a tributary channel that empties into the main Ares Vallis channel." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23596_hires.jpg" data-link="/spaceimages/details.php?id=PIA23596" data-thumbnail="/spaceimages/images/wallpaper/PIA23596-640x350.jpg" data-title="Ares Vallis Tributary - False Color">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 16, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Ares Vallis Tributary - False Color
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Ares Vallis Tributary - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23596-640x350.jpg" title="Ares Vallis Tributary - False Color"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 16, 2019
#             </div>
#             <div class="content_title">
#              Ares Vallis Tributary - False Color
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows a tributary channel that empties into the main Ares Vallis channel.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a field of dunes on the floor of an unnamed crater near Schiaparelli Crater in Noachis Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23580_hires.jpg" data-link="/spaceimages/details.php?id=PIA23580" data-thumbnail="/spaceimages/images/wallpaper/PIA23580-640x350.jpg" data-title="Crater Dunes">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 13, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Crater Dunes
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23580-640x350.jpg" title="Crater Dunes"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 13, 2019
#             </div>
#             <div class="content_title">
#              Crater Dunes
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows a field of dunes on the floor of an unnamed crater near Schiaparelli Crater in Noachis Terra.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23579_hires.jpg" data-link="/spaceimages/details.php?id=PIA23579" data-thumbnail="/spaceimages/images/wallpaper/PIA23579-640x350.jpg" data-title="Hephaestus Fossae">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 12, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Hephaestus Fossae
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Hephaestus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23579-640x350.jpg" title="Hephaestus Fossae"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 12, 2019
#             </div>
#             <div class="content_title">
#              Hephaestus Fossae
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows huge regions of complex valleys and chaos, located in Xanthe and Margaritifer Terras." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23578_hires.jpg" data-link="/spaceimages/details.php?id=PIA23578" data-thumbnail="/spaceimages/images/wallpaper/PIA23578-640x350.jpg" data-title="Chryse Chaos">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 11, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Chryse Chaos
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Chryse Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23578-640x350.jpg" title="Chryse Chaos"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 11, 2019
#             </div>
#             <div class="content_title">
#              Chryse Chaos
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows huge regions of complex valleys and chaos, located in Xanthe and Margaritifer Terras.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="In this illustration, Mars holds near-surface water ice that would be easily accessible for astronauts to dig up. The water ice was identified as part of a map using data from NASA orbiters." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23515_hires.jpg" data-link="/spaceimages/details.php?id=PIA23515" data-thumbnail="/spaceimages/images/wallpaper/PIA23515-640x350.jpg" data-title="Water Ice Marked on Mars Globe (Illustration)">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 10, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Water Ice Marked on Mars Globe (Illustration)
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Water Ice Marked on Mars Globe (Illustration)" class="thumb" src="/spaceimages/images/wallpaper/PIA23515-640x350.jpg" title="Water Ice Marked on Mars Globe (Illustration)"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 10, 2019
#             </div>
#             <div class="content_title">
#              Water Ice Marked on Mars Globe (Illustration)
#             </div>
#             <div class="article_teaser_body">
#              In this illustration, Mars holds near-surface water ice that would be easily accessible for astronauts to dig up. The water ice was identified as part of a map using data from NASA orbiters.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This rainbow-colored map shows underground water ice on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23514_hires.jpg" data-link="/spaceimages/details.php?id=PIA23514" data-thumbnail="/spaceimages/images/wallpaper/PIA23514-640x350.jpg" data-title="A Water Ice Map for Mars">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 10, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              A Water Ice Map for Mars
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="A Water Ice Map for Mars" class="thumb" src="/spaceimages/images/wallpaper/PIA23514-640x350.jpg" title="A Water Ice Map for Mars"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 10, 2019
#             </div>
#             <div class="content_title">
#              A Water Ice Map for Mars
#             </div>
#             <div class="article_teaser_body">
#              This rainbow-colored map shows underground water ice on Mars.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a large enclosed basin, located in Margaritifer Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23577_hires.jpg" data-link="/spaceimages/details.php?id=PIA23577" data-thumbnail="/spaceimages/images/wallpaper/PIA23577-640x350.jpg" data-title="Margaritifer Terra">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 10, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Margaritifer Terra
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Margaritifer Terra" class="thumb" src="/spaceimages/images/wallpaper/PIA23577-640x350.jpg" title="Margaritifer Terra"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 10, 2019
#             </div>
#             <div class="content_title">
#              Margaritifer Terra
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows a large enclosed basin, located in Margaritifer Terra.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Medusa Fossae. Winds have eroded materials in this region, creating ridges and valleys aligned with the direction of the wind." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23576_hires.jpg" data-link="/spaceimages/details.php?id=PIA23576" data-thumbnail="/spaceimages/images/wallpaper/PIA23576-640x350.jpg" data-title="Medusae Fossae">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 9, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Medusae Fossae
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Medusae Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23576-640x350.jpg" title="Medusae Fossae"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 9, 2019
#             </div>
#             <div class="content_title">
#              Medusae Fossae
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of Medusa Fossae. Winds have eroded materials in this region, creating ridges and valleys aligned with the direction of the wind.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the complex caldera at the summit of Ascraeus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23575_hires.jpg" data-link="/spaceimages/details.php?id=PIA23575" data-thumbnail="/spaceimages/images/wallpaper/PIA23575-640x350.jpg" data-title="Ascraeus Mons">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 6, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Ascraeus Mons
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Ascraeus Mons" class="thumb" src="/spaceimages/images/wallpaper/PIA23575-640x350.jpg" title="Ascraeus Mons"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 6, 2019
#             </div>
#             <div class="content_title">
#              Ascraeus Mons
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of the complex caldera at the summit of Ascraeus Mons.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Hypanis Valles." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23574_hires.jpg" data-link="/spaceimages/details.php?id=PIA23574" data-thumbnail="/spaceimages/images/wallpaper/PIA23574-640x350.jpg" data-title="Hypanis Valles">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 5, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Hypanis Valles
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Hypanis Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23574-640x350.jpg" title="Hypanis Valles"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 5, 2019
#             </div>
#             <div class="content_title">
#              Hypanis Valles
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows a section of Hypanis Valles.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Indus Vallis, located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23573_hires.jpg" data-link="/spaceimages/details.php?id=PIA23573" data-thumbnail="/spaceimages/images/wallpaper/PIA23573-640x350.jpg" data-title="Indus Vallis">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 4, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Indus Vallis
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Indus Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23573-640x350.jpg" title="Indus Vallis"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 4, 2019
#             </div>
#             <div class="content_title">
#              Indus Vallis
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of Indus Vallis, located in northern Terra Sabaea.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Huo Hsing Valles, located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23572_hires.jpg" data-link="/spaceimages/details.php?id=PIA23572" data-thumbnail="/spaceimages/images/wallpaper/PIA23572-640x350.jpg" data-title="Huo Hsing Vallis">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 3, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Huo Hsing Vallis
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Huo Hsing Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23572-640x350.jpg" title="Huo Hsing Vallis"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 3, 2019
#             </div>
#             <div class="content_title">
#              Huo Hsing Vallis
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of Huo Hsing Valles, located in northern Terra Sabaea.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of one of the many channel forms found radial to the Elysium Mons volcanic complex." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23571_hires.jpg" data-link="/spaceimages/details.php?id=PIA23571" data-thumbnail="/spaceimages/images/wallpaper/PIA23571-640x350.jpg" data-title="Elysium Fossae">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              December 2, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Elysium Fossae
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Elysium Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23571-640x350.jpg" title="Elysium Fossae"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              December 2, 2019
#             </div>
#             <div class="content_title">
#              Elysium Fossae
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows a section of one of the many channel forms found radial to the Elysium Mons volcanic complex.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Maja Valles, a large channel system in Lunae Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23570_hires.jpg" data-link="/spaceimages/details.php?id=PIA23570" data-thumbnail="/spaceimages/images/wallpaper/PIA23570-640x350.jpg" data-title="Maja Valles Tributary">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              November 29, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Maja Valles Tributary
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Maja Valles Tributary" class="thumb" src="/spaceimages/images/wallpaper/PIA23570-640x350.jpg" title="Maja Valles Tributary"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              November 29, 2019
#             </div>
#             <div class="content_title">
#              Maja Valles Tributary
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of Maja Valles, a large channel system in Lunae Planum.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Ophir Chasma. Ophir Chasma is part of Valles Marineris, the largest canyon system on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23569_hires.jpg" data-link="/spaceimages/details.php?id=PIA23569" data-thumbnail="/spaceimages/images/wallpaper/PIA23569-640x350.jpg" data-title="Ophir Chasma Landslide">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             <h3 class="release_date">
#              November 28, 2019
#             </h3>
#             <div class="item_tease_overlay">
#              Ophir Chasma Landslide
#             </div>
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <div class="img">
#             <img alt="Ophir Chasma Landslide" class="thumb" src="/spaceimages/images/wallpaper/PIA23569-640x350.jpg" title="Ophir Chasma Landslide"/>
#            </div>
#            <div class="list_text_content">
#             <div class="article_teaser_body">
#              November 28, 2019
#             </div>
#             <div class="content_title">
#              Ophir Chasma Landslide
#             </div>
#             <div class="article_teaser_body">
#              This image from NASAs Mars Odyssey shows part of Ophir Chasma. Ophir Chasma is part of Valles Marineris, the largest canyon system on Mars.
#             </div>
#            </div>
#           </div>
#          </a>
#         </li>
#         <li class="slide">
# ...
#             In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="NASA's Mars 2020 rover" src="//imagecache.jpl.nasa.gov/images/640x350/PIA23499-16-640x350.jpg"/>
#           </div>
#           <div class="content_title">
#            NASA's Mars 2020 Rover Completes Its First Drive
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="//www.jpl.nasa.gov/news/news.php?feature=7561">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             To celebrate the 10th anniversary of the spacecraft's launch, the mission team has gathered their top 10 images and graphics related to the two missions related to it.
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Neowise image" src="//imagecache.jpl.nasa.gov/images/640x350/1-NEOWISE-WISEfullsky-16-640x350.jpg"/>
#           </div>
#           <div class="content_title">
#            Celebrating 10 Years of the WISE Spacecraft
#           </div>
#          </a>
#         </li>
#         <li class="slide">
#          <a href="//www.jpl.nasa.gov/news/news.php?feature=7560">
#           <div class="image_and_description_container">
#            <div class="rollover_description">
#             When the Juno team maneuvered the spacecraft to avoid a mission-ending eclipse, they paved the way for it to discover a new cyclone at Jupiter's south pole.
#             <div class="overlay_arrow">
#              <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#             </div>
#            </div>
#            <img alt="Infrared image of Jupiter's south pole" src="//imagecache.jpl.nasa.gov/images/640x350/PIA23558-16-640x350.jpg"/>
#           </div>
#           <div class="content_title">
#            NASA's Juno Navigators Enable Jupiter Cyclone Discovery
#           </div>
#          </a>
#         </li>
#        </ul>
#        <footer>
#         <a class="outline_button dark" href="/news">
#          more news
#         </a>
#        </footer>
#       </div>
#      </section>
#      <!-- END CONTENT -->
#      <script src="/Scripts/custom_detail.js" type="text/javascript">
#      </script>
#      <!-- START FOOTER: "DEFAULT" -->
#     </div>
#     <footer class="clearfix" id="site_footer">
#      <section class="upper_footer">
#       <div class="grid_layout">
#        <div class="footer_newsletter">
#         <h2>
#          Get the Newsletter
#         </h2>
#         <form action="/signup/index.php" class="submit_newsletter" method="post">
#          <input class="email_field" name="email_field" onblur="this.placeholder = 'enter email address'" onfocus="this.placeholder = ''" placeholder="enter email address" type="email" value=""/>
#          <input class="email_submit" type="submit" value=""/>
#         </form>
#        </div>
#        <div class="gradient_line_divider">
#        </div>
#        <div class="share">
#         <h2>
#          Follow JPL
#         </h2>
#         <div class="social_icons">
#          <!-- AddThis Button BEGIN -->
#          <div class="addthis_toolbox addthis_default_style addthis_32x32_style">
#           <a addthis:userid="NASAJPL" class="addthis_button_facebook_follow icon">
#           </a>
#           <a addthis:userid="NASAJPL" class="addthis_button_twitter_follow icon">
#           </a>
#           <a addthis:userid="JPLnews" class="addthis_button_youtube_follow icon">
#           </a>
#           <a addthis:userid="nasajpl" class="addthis_button_instagram_follow icon">
#           </a>
#           <a class="icon all_icon" href="/social">
#            <span>
#             All
#            </span>
#           </a>
#          </div>
#          <script>
#           addthis_loader.init("//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5429eeee4e460927", {follow: true})
#          </script>
#         </div>
#        </div>
#       </div>
#       <div class="gradient_line">
#       </div>
#      </section>
#      <section class="sitemap">
#       <div class="grid_layout">
#        <div class="sitemap_directory">
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            about JPL
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/about/">
#              About JPL
#             </a>
#            </li>
#            <li>
#             <a href="https://www.jpl.nasa.gov/jpl2025/vision/">
#              JPL Vision
#             </a>
#            </li>
#            <li>
#             <a href="/about/exec.php">
#              Executive Council
#             </a>
#            </li>
#            <li>
#             <a href="/about/history.php">
#              History
#             </a>
#            </li>
#            <li>
#             <a href="/about/reports.php">
#              Annual Reports
#             </a>
#            </li>
#            <li>
#             <a href="/contact_JPL.php">
#              Contact Us
#             </a>
#            </li>
#            <li>
#             <a href="/opportunities/">
#              Opportunities
#             </a>
#            </li>
#            <li>
#             <a href="https://thejplstore.com" target="_blank">
#              JPL Online Store
#             </a>
#            </li>
#            <li>
#             <a href="/acquisition/">
#              Doing Business with JPL
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            missions
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/missions/?type=current">
#              Current
#             </a>
#            </li>
#            <li>
#             <a href="/missions/?type=past">
#              Past
#             </a>
#            </li>
#            <li>
#             <a href="/missions/?type=future">
#              Future
#             </a>
#            </li>
#            <li>
#             <a href="/missions/?type=proposed">
#              Proposed
#             </a>
#            </li>
#            <li>
#             <a href="/missions">
#              All
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            education
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/edu/intern/">
#              Intern
#             </a>
#            </li>
#            <li>
#             <a href="/edu/learn/">
#              Learn
#             </a>
#            </li>
#            <li>
#             <a href="/edu/teach/">
#              Teach
#             </a>
#            </li>
#            <li>
#             <a href="/edu/news/">
#              News
#             </a>
#            </li>
#            <li>
#             <a href="/edu/events/">
#              Events
#             </a>
#            </li>
#            <li>
#             <a href="https://spaceplace.nasa.gov/menu/play/">
#              Games
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            news
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/news">
#              Latest News
#             </a>
#            </li>
#            <li>
#             <a href="/news/presskits.php">
#              Press Kits
#             </a>
#            </li>
#            <li>
#             <a href="/news/factsheets.php">
#              Fact Sheets
#             </a>
#            </li>
#            <li>
#             <a href="/news/mediainformation.php">
#              Media Information
#             </a>
#            </li>
#            <li>
#             <a href="/universe/">
#              Universe Newspaper
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            public events
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/events/">
#              Overview
#             </a>
#            </li>
#            <li>
#             <a href="/events/tours/views/">
#              Tours
#             </a>
#            </li>
#            <li>
#             <a href="/events/lectures.php">
#              Lecture Series
#             </a>
#            </li>
#            <li>
#             <a href="/events/speakers-bureau.php">
#              Speakers Bureau
#             </a>
#            </li>
#            <li>
#             <a href="/events/team-competitions.php">
#              Team Competitions
#             </a>
#            </li>
#            <li>
#             <a href="/events/special-events.php">
#              Special Events
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            Our Sites
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/asteroidwatch/">
#              Asteroid Watch
#             </a>
#            </li>
#            <li>
#             <a href="https://solarsystem.nasa.gov/basics/" target="_blank">
#              Basics of Spaceflight
#             </a>
#            </li>
#            <li>
#             <a href="http://saturn.jpl.nasa.gov/index.cfm">
#              Cassini - Mission to Saturn
#             </a>
#            </li>
#            <li>
#             <a href="http://climate.nasa.gov">
#              Earth / Global Climate Change
#             </a>
#            </li>
#            <li>
#             <a href="http://planetquest.jpl.nasa.gov">
#              Exoplanet Exploration
#             </a>
#            </li>
#            <li>
#             <a href="/missions/juno/">
#              Juno - Mission to Jupiter
#             </a>
#            </li>
#            <li>
#             <a href="https://mars.nasa.gov/">
#              Mars Exploration
#             </a>
#            </li>
#            <li>
#             <a href="http://scienceandtechnology.jpl.nasa.gov/">
#              Science and Technology
#             </a>
#            </li>
#            <li>
#             <a href="http://solarsystem.nasa.gov/">
#              Solar System Exploration
#             </a>
#            </li>
#            <li>
#             <a href="https://eyes.nasa.gov/">
#              NASA's Eyes
#             </a>
#            </li>
#            <li>
#             <a href="http://www.spitzer.caltech.edu/">
#              Spitzer Space Telescope
#             </a>
#            </li>
#            <li>
#             <a href="https://voyager.jpl.nasa.gov/">
#              Voyager Interstellar Mission
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            galleries
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/spaceimages/">
#              JPL Space Images
#             </a>
#            </li>
#            <li>
#             <a href="/videos/">
#              Videos
#             </a>
#            </li>
#            <li>
#             <a href="/infographics/">
#              Infographics
#             </a>
#            </li>
#            <li>
#             <a href="https://photojournal.jpl.nasa.gov/">
#              Photojournal
#             </a>
#            </li>
#            <li>
#             <a href="http://www.nasaimages.org/">
#              NASA Images
#             </a>
#            </li>
#            <li>
#             <a href="/apps/">
#              Mobile Apps
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="sitemap_block">
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            Follow JPL
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="/signup/">
#              Newsletter
#             </a>
#            </li>
#            <li>
#             <a href="https://www.facebook.com/NASAJPL">
#              Facebook
#             </a>
#            </li>
#            <li>
#             <a href="http://twitter.com/NASAJPL">
#              Twitter
#             </a>
#            </li>
#            <li>
#             <a href="http://www.youtube.com/user/JPLnews">
#              YouTube
#             </a>
#            </li>
#            <li>
#             <a href="http://www.flickr.com/photos/nasa-jpl">
#              Flickr
#             </a>
#            </li>
#            <li>
#             <a href="http://instagram.com/nasajpl">
#              Instagram
#             </a>
#            </li>
#            <li>
#             <a href="https://www.linkedin.com/company/2004/">
#              LinkedIn
#             </a>
#            </li>
#            <li>
#             <a href="http://itunes.apple.com/podcast/hd-nasas-jet-propulsion-laboratory/id262254981">
#              iTunes
#             </a>
#            </li>
#            <li>
#             <a href="http://www.ustream.tv/nasajpl">
#              UStream
#             </a>
#            </li>
#            <li>
#             <a href="/rss/">
#              RSS
#             </a>
#            </li>
#            <li>
#             <a href="http://blogs.jpl.nasa.gov">
#              Blog
#             </a>
#            </li>
#            <li>
#             <a href="/onthego/">
#              Mobile
#             </a>
#            </li>
#            <li>
#             <a href="/social/">
#              All Social Media
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="footer_sitemap_item">
#           <h3 class="sitemap_title">
#            NASA
#           </h3>
#           <ul class="subnav">
#            <li>
#             <a href="http://jplwater.nasa.gov">
#              NASA Water Cleanup
#             </a>
#            </li>
#            <li>
#             <a href="http://www.hq.nasa.gov/office/pao/FOIA/agency/">
#              FOIA
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="gradient_line">
#       </div>
#      </section>
#      <section class="lower_footer">
#       <div class="nav_container">
#        <nav>
#         <ul>
#          <li>
#           <a href="http://www.nasa.gov/" target="_blank">
#            NASA
#           </a>
#          </li>
#          |
#          <li>
#           <a href="http://www.caltech.edu/" target="_blank">
#            Caltech
#           </a>
#          </li>
#          |
#          <li>
#           <a href="/privacy">
#            Privacy
#           </a>
#          </li>
#          |
#          <li>
#           <a href="/imagepolicy">
#            Image Policy
#           </a>
#          </li>
#          |
#          <li>
#           <a href="/faq.php">
#            FAQ
#           </a>
#          </li>
#          |
#          <li>
#           <a href="/contact_JPL.php">
#            Feedback
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#       <div class="credits">
#        <span class="credits_manager">
#         Site Manager: Jon Nelson
#        </span>
#        <span class="credits_webmaster">
#         Webmasters: Anil Natha, Luis Espinoza, Tony Greicius
#        </span>
#       </div>
#      </section>
#     </footer>
#    </div>
#   </div>
#   <script src="/assets/javascripts/vendor/prefixfree.js" type="text/javascript">
#   </script>
#   <script src="/assets/javascripts/vendor/prefixfree.jquery.js" type="text/javascript">
#   </script>
#   <script id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=NASA&amp;pua=UA-45212297-1&amp;subagency=JPL&amp;dclink=true&amp;sp=search,s,q&amp;sdor=false&amp;exts=tif,tiff" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0025/5267.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
#   </script>
#  </body>
#  <!-- END FOOTER: "DEFAULT" -->
# </html>

# %%
imgs = soup.find_all('a', class_="fancybox")
imgs
# Out:
# [<a class="button fancybox" data-description="NASA's Cassini spacecraft reveals the differences in the composition of surface materials around hydrocarbon lakes at Titan." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA17470_ip.jpg" data-link="/spaceimages/details.php?id=PIA17470" data-title="Titan's Northern Lakes: Salt Flats?" id="full_image">
#  					FULL IMAGE
#  				  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of an unnamed crater in Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23599_hires.jpg" data-link="/spaceimages/details.php?id=PIA23599" data-thumbnail="/spaceimages/images/wallpaper/PIA23599-640x350.jpg" data-title="Terra Sabaea Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 19, 2019</h3>
#  <div class="item_tease_overlay">Terra Sabaea Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Sabaea Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23599-640x350.jpg" title="Terra Sabaea Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 19, 2019</div>
#  <div class="content_title">
#  										  Terra Sabaea Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the floor of an unnamed crater in Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the inner rim, central peak ring and floor of Sagan Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23598_hires.jpg" data-link="/spaceimages/details.php?id=PIA23598" data-thumbnail="/spaceimages/images/wallpaper/PIA23598-640x350.jpg" data-title="Sagan Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 18, 2019</h3>
#  <div class="item_tease_overlay">Sagan Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Sagan Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23598-640x350.jpg" title="Sagan Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 18, 2019</div>
#  <div class="content_title">
#  										  Sagan Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the inner rim, central peak ring and floor of Sagan Crater.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This map of the Red Planet shows Jezero Crater, where NASAs Mars 2020 rover is scheduled to land in February 2021." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23518_hires.jpg" data-link="/spaceimages/details.php?id=PIA23518" data-thumbnail="/spaceimages/images/wallpaper/PIA23518-640x350.jpg" data-title="Map of NASA" landing="" mars="" s="" sites'="">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 17, 2019</h3>
#  <div class="item_tease_overlay">Map of NASA's Mars Landing Sites</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Map of NASA" class="thumb" landing="" mars="" s="" sites'="" src="/spaceimages/images/wallpaper/PIA23518-640x350.jpg" title="Map of NASA"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 17, 2019</div>
#  <div class="content_title">
#  										  Map of NASA's Mars Landing Sites
#  										</div>
#  <div class="article_teaser_body">
#  										  This map of the Red Planet shows Jezero Crater, where NASAs Mars 2020 rover is scheduled to land in February 2021.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the interior of Crommelin Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23597_hires.jpg" data-link="/spaceimages/details.php?id=PIA23597" data-thumbnail="/spaceimages/images/wallpaper/PIA23597-640x350.jpg" data-title="Crommelin Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 17, 2019</h3>
#  <div class="item_tease_overlay">Crommelin Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Crommelin Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23597-640x350.jpg" title="Crommelin Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 17, 2019</div>
#  <div class="content_title">
#  										  Crommelin Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the interior of Crommelin Crater.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a tributary channel that empties into the main Ares Vallis channel." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23596_hires.jpg" data-link="/spaceimages/details.php?id=PIA23596" data-thumbnail="/spaceimages/images/wallpaper/PIA23596-640x350.jpg" data-title="Ares Vallis Tributary - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 16, 2019</h3>
#  <div class="item_tease_overlay">Ares Vallis Tributary - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ares Vallis Tributary - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23596-640x350.jpg" title="Ares Vallis Tributary - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 16, 2019</div>
#  <div class="content_title">
#  										  Ares Vallis Tributary - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a tributary channel that empties into the main Ares Vallis channel.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a field of dunes on the floor of an unnamed crater near Schiaparelli Crater in Noachis Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23580_hires.jpg" data-link="/spaceimages/details.php?id=PIA23580" data-thumbnail="/spaceimages/images/wallpaper/PIA23580-640x350.jpg" data-title="Crater Dunes">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 13, 2019</h3>
#  <div class="item_tease_overlay">Crater Dunes</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23580-640x350.jpg" title="Crater Dunes"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 13, 2019</div>
#  <div class="content_title">
#  										  Crater Dunes
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a field of dunes on the floor of an unnamed crater near Schiaparelli Crater in Noachis Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23579_hires.jpg" data-link="/spaceimages/details.php?id=PIA23579" data-thumbnail="/spaceimages/images/wallpaper/PIA23579-640x350.jpg" data-title="Hephaestus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 12, 2019</h3>
#  <div class="item_tease_overlay">Hephaestus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hephaestus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23579-640x350.jpg" title="Hephaestus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 12, 2019</div>
#  <div class="content_title">
#  										  Hephaestus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows huge regions of complex valleys and chaos, located in Xanthe and Margaritifer Terras." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23578_hires.jpg" data-link="/spaceimages/details.php?id=PIA23578" data-thumbnail="/spaceimages/images/wallpaper/PIA23578-640x350.jpg" data-title="Chryse Chaos">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 11, 2019</h3>
#  <div class="item_tease_overlay">Chryse Chaos</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Chryse Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23578-640x350.jpg" title="Chryse Chaos"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 11, 2019</div>
#  <div class="content_title">
#  										  Chryse Chaos
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows huge regions of complex valleys and chaos, located in Xanthe and Margaritifer Terras.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="In this illustration, Mars holds near-surface water ice that would be easily accessible for astronauts to dig up. The water ice was identified as part of a map using data from NASA orbiters." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23515_hires.jpg" data-link="/spaceimages/details.php?id=PIA23515" data-thumbnail="/spaceimages/images/wallpaper/PIA23515-640x350.jpg" data-title="Water Ice Marked on Mars Globe (Illustration)">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 10, 2019</h3>
#  <div class="item_tease_overlay">Water Ice Marked on Mars Globe (Illustration)</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Water Ice Marked on Mars Globe (Illustration)" class="thumb" src="/spaceimages/images/wallpaper/PIA23515-640x350.jpg" title="Water Ice Marked on Mars Globe (Illustration)"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 10, 2019</div>
#  <div class="content_title">
#  										  Water Ice Marked on Mars Globe (Illustration)
#  										</div>
#  <div class="article_teaser_body">
#  										  In this illustration, Mars holds near-surface water ice that would be easily accessible for astronauts to dig up. The water ice was identified as part of a map using data from NASA orbiters.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This rainbow-colored map shows underground water ice on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23514_hires.jpg" data-link="/spaceimages/details.php?id=PIA23514" data-thumbnail="/spaceimages/images/wallpaper/PIA23514-640x350.jpg" data-title="A Water Ice Map for Mars">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 10, 2019</h3>
#  <div class="item_tease_overlay">A Water Ice Map for Mars</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="A Water Ice Map for Mars" class="thumb" src="/spaceimages/images/wallpaper/PIA23514-640x350.jpg" title="A Water Ice Map for Mars"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 10, 2019</div>
#  <div class="content_title">
#  										  A Water Ice Map for Mars
#  										</div>
#  <div class="article_teaser_body">
#  										  This rainbow-colored map shows underground water ice on Mars.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a large enclosed basin, located in Margaritifer Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23577_hires.jpg" data-link="/spaceimages/details.php?id=PIA23577" data-thumbnail="/spaceimages/images/wallpaper/PIA23577-640x350.jpg" data-title="Margaritifer Terra">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 10, 2019</h3>
#  <div class="item_tease_overlay">Margaritifer Terra</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Margaritifer Terra" class="thumb" src="/spaceimages/images/wallpaper/PIA23577-640x350.jpg" title="Margaritifer Terra"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 10, 2019</div>
#  <div class="content_title">
#  										  Margaritifer Terra
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a large enclosed basin, located in Margaritifer Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Medusa Fossae. Winds have eroded materials in this region, creating ridges and valleys aligned with the direction of the wind." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23576_hires.jpg" data-link="/spaceimages/details.php?id=PIA23576" data-thumbnail="/spaceimages/images/wallpaper/PIA23576-640x350.jpg" data-title="Medusae Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 9, 2019</h3>
#  <div class="item_tease_overlay">Medusae Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Medusae Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23576-640x350.jpg" title="Medusae Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 9, 2019</div>
#  <div class="content_title">
#  										  Medusae Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Medusa Fossae. Winds have eroded materials in this region, creating ridges and valleys aligned with the direction of the wind.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the complex caldera at the summit of Ascraeus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23575_hires.jpg" data-link="/spaceimages/details.php?id=PIA23575" data-thumbnail="/spaceimages/images/wallpaper/PIA23575-640x350.jpg" data-title="Ascraeus Mons">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 6, 2019</h3>
#  <div class="item_tease_overlay">Ascraeus Mons</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ascraeus Mons" class="thumb" src="/spaceimages/images/wallpaper/PIA23575-640x350.jpg" title="Ascraeus Mons"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 6, 2019</div>
#  <div class="content_title">
#  										  Ascraeus Mons
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the complex caldera at the summit of Ascraeus Mons.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Hypanis Valles." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23574_hires.jpg" data-link="/spaceimages/details.php?id=PIA23574" data-thumbnail="/spaceimages/images/wallpaper/PIA23574-640x350.jpg" data-title="Hypanis Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 5, 2019</h3>
#  <div class="item_tease_overlay">Hypanis Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hypanis Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23574-640x350.jpg" title="Hypanis Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 5, 2019</div>
#  <div class="content_title">
#  										  Hypanis Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Hypanis Valles.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Indus Vallis, located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23573_hires.jpg" data-link="/spaceimages/details.php?id=PIA23573" data-thumbnail="/spaceimages/images/wallpaper/PIA23573-640x350.jpg" data-title="Indus Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 4, 2019</h3>
#  <div class="item_tease_overlay">Indus Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Indus Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23573-640x350.jpg" title="Indus Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 4, 2019</div>
#  <div class="content_title">
#  										  Indus Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Indus Vallis, located in northern Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Huo Hsing Valles, located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23572_hires.jpg" data-link="/spaceimages/details.php?id=PIA23572" data-thumbnail="/spaceimages/images/wallpaper/PIA23572-640x350.jpg" data-title="Huo Hsing Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 3, 2019</h3>
#  <div class="item_tease_overlay">Huo Hsing Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Huo Hsing Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23572-640x350.jpg" title="Huo Hsing Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 3, 2019</div>
#  <div class="content_title">
#  										  Huo Hsing Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Huo Hsing Valles, located in northern Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of one of the many channel forms found radial to the Elysium Mons volcanic complex." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23571_hires.jpg" data-link="/spaceimages/details.php?id=PIA23571" data-thumbnail="/spaceimages/images/wallpaper/PIA23571-640x350.jpg" data-title="Elysium Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 2, 2019</h3>
#  <div class="item_tease_overlay">Elysium Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Elysium Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23571-640x350.jpg" title="Elysium Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 2, 2019</div>
#  <div class="content_title">
#  										  Elysium Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of one of the many channel forms found radial to the Elysium Mons volcanic complex.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Maja Valles, a large channel system in Lunae Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23570_hires.jpg" data-link="/spaceimages/details.php?id=PIA23570" data-thumbnail="/spaceimages/images/wallpaper/PIA23570-640x350.jpg" data-title="Maja Valles Tributary">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 29, 2019</h3>
#  <div class="item_tease_overlay">Maja Valles Tributary</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Maja Valles Tributary" class="thumb" src="/spaceimages/images/wallpaper/PIA23570-640x350.jpg" title="Maja Valles Tributary"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 29, 2019</div>
#  <div class="content_title">
#  										  Maja Valles Tributary
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Maja Valles, a large channel system in Lunae Planum.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Ophir Chasma. Ophir Chasma is part of Valles Marineris, the largest canyon system on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23569_hires.jpg" data-link="/spaceimages/details.php?id=PIA23569" data-thumbnail="/spaceimages/images/wallpaper/PIA23569-640x350.jpg" data-title="Ophir Chasma Landslide">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 28, 2019</h3>
#  <div class="item_tease_overlay">Ophir Chasma Landslide</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ophir Chasma Landslide" class="thumb" src="/spaceimages/images/wallpaper/PIA23569-640x350.jpg" title="Ophir Chasma Landslide"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 28, 2019</div>
#  <div class="content_title">
#  										  Ophir Chasma Landslide
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Ophir Chasma. Ophir Chasma is part of Valles Marineris, the largest canyon system on Mars.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image acquired on September 15, 2019 by NASAs Mars Reconnaissance Orbiter, shows the floor of an old impact crater in Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23584_hires.jpg" data-link="/spaceimages/details.php?id=PIA23584" data-thumbnail="/spaceimages/images/wallpaper/PIA23584-640x350.jpg" data-title="Both Ancient and Modern">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 27, 2019</h3>
#  <div class="item_tease_overlay">Both Ancient and Modern</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Both Ancient and Modern" class="thumb" src="/spaceimages/images/wallpaper/PIA23584-640x350.jpg" title="Both Ancient and Modern"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 27, 2019</div>
#  <div class="content_title">
#  										  Both Ancient and Modern
#  										</div>
#  <div class="article_teaser_body">
#  										  This image acquired on September 15, 2019 by NASAs Mars Reconnaissance Orbiter, shows the floor of an old impact crater in Arabia Terra.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image acquired on August 8, 2019 by NASAs Mars Reconnaissance Orbiter, shows layered sediments on the floor of eastern Coprates Chasma in Valles Marineris, the grandest canyon on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23583_hires.jpg" data-link="/spaceimages/details.php?id=PIA23583" data-thumbnail="/spaceimages/images/wallpaper/PIA23583-640x350.jpg" data-title="Layered Sediments in Valles Marineris">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 27, 2019</h3>
#  <div class="item_tease_overlay">Layered Sediments in Valles Marineris</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Layered Sediments in Valles Marineris" class="thumb" src="/spaceimages/images/wallpaper/PIA23583-640x350.jpg" title="Layered Sediments in Valles Marineris"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 27, 2019</div>
#  <div class="content_title">
#  										  Layered Sediments in Valles Marineris
#  										</div>
#  <div class="article_teaser_body">
#  										  This image acquired on August 8, 2019 by NASAs Mars Reconnaissance Orbiter, shows layered sediments on the floor of eastern Coprates Chasma in Valles Marineris, the grandest canyon on Mars.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image acquired on July 21, 2019 by NASAs Mars Reconnaissance Orbiter, shows the mid-latitudes of Mars, draped with deposits of water ice and dust on the order of tens of meters thick." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23582_hires.jpg" data-link="/spaceimages/details.php?id=PIA23582" data-thumbnail="/spaceimages/images/wallpaper/PIA23582-640x350.jpg" data-title="Pits, Hollows and Viscous Flow">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 27, 2019</h3>
#  <div class="item_tease_overlay">Pits, Hollows and Viscous Flow</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Pits, Hollows and Viscous Flow" class="thumb" src="/spaceimages/images/wallpaper/PIA23582-640x350.jpg" title="Pits, Hollows and Viscous Flow"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 27, 2019</div>
#  <div class="content_title">
#  										  Pits, Hollows and Viscous Flow
#  										</div>
#  <div class="article_teaser_body">
#  										  This image acquired on July 21, 2019 by NASAs Mars Reconnaissance Orbiter, shows the mid-latitudes of Mars, draped with deposits of water ice and dust on the order of tens of meters thick.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image acquired on July 8, 2019 by NASAs Mars Reconnaissance Orbiter, shows spring in the Northern Hemisphere of Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23581_hires.jpg" data-link="/spaceimages/details.php?id=PIA23581" data-thumbnail="/spaceimages/images/wallpaper/PIA23581-640x350.jpg" data-title="Polygonal Patterns Highlighted by Frost">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 27, 2019</h3>
#  <div class="item_tease_overlay">Polygonal Patterns Highlighted by Frost</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Polygonal Patterns Highlighted by Frost" class="thumb" src="/spaceimages/images/wallpaper/PIA23581-640x350.jpg" title="Polygonal Patterns Highlighted by Frost"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 27, 2019</div>
#  <div class="content_title">
#  										  Polygonal Patterns Highlighted by Frost
#  										</div>
#  <div class="article_teaser_body">
#  										  This image acquired on July 8, 2019 by NASAs Mars Reconnaissance Orbiter, shows spring in the Northern Hemisphere of Mars.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows linear depressions that are some of the graben that comprise Cerberus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23568_hires.jpg" data-link="/spaceimages/details.php?id=PIA23568" data-thumbnail="/spaceimages/images/wallpaper/PIA23568-640x350.jpg" data-title="Cerberus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 27, 2019</h3>
#  <div class="item_tease_overlay">Cerberus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Cerberus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23568-640x350.jpg" title="Cerberus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 27, 2019</div>
#  <div class="content_title">
#  										  Cerberus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows linear depressions that are some of the graben that comprise Cerberus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image, taken on Nov. 30, 2010, by NASAs Mars Reconnaissance Orbiter, shows a Mars dust tower, a concentrated cloud of dust that can be lofted dozens of miles above the surface." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23513_hires.jpg" data-link="/spaceimages/details.php?id=PIA23513" data-thumbnail="/spaceimages/images/wallpaper/PIA23513-640x350.jpg" data-title="A Mars Dust Tower Stands Out">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 26, 2019</h3>
#  <div class="item_tease_overlay">A Mars Dust Tower Stands Out</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="A Mars Dust Tower Stands Out" class="thumb" src="/spaceimages/images/wallpaper/PIA23513-640x350.jpg" title="A Mars Dust Tower Stands Out"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 26, 2019</div>
#  <div class="content_title">
#  										  A Mars Dust Tower Stands Out
#  										</div>
#  <div class="article_teaser_body">
#  										  This image, taken on Nov. 30, 2010, by NASAs Mars Reconnaissance Orbiter, shows a Mars dust tower, a concentrated cloud of dust that can be lofted dozens of miles above the surface.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a large crater called Gandzani Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23567_hires.jpg" data-link="/spaceimages/details.php?id=PIA23567" data-thumbnail="/spaceimages/images/wallpaper/PIA23567-640x350.jpg" data-title="Gandzani Crater">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 26, 2019</h3>
#  <div class="item_tease_overlay">Gandzani Crater</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Gandzani Crater" class="thumb" src="/spaceimages/images/wallpaper/PIA23567-640x350.jpg" title="Gandzani Crater"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 26, 2019</div>
#  <div class="content_title">
#  										  Gandzani Crater
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a large crater called Gandzani Crater.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the northern margin of Acheron Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23566_hires.jpg" data-link="/spaceimages/details.php?id=PIA23566" data-thumbnail="/spaceimages/images/wallpaper/PIA23566-640x350.jpg" data-title="Acheron Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 25, 2019</h3>
#  <div class="item_tease_overlay">Acheron Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Acheron Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23566-640x350.jpg" title="Acheron Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 25, 2019</div>
#  <div class="content_title">
#  										  Acheron Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the northern margin of Acheron Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a portion of Kasei Valles. In the region of this image Kasei Valles is flowing northward from Vallis Marineris." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23565_hires.jpg" data-link="/spaceimages/details.php?id=PIA23565" data-thumbnail="/spaceimages/images/wallpaper/PIA23565-640x350.jpg" data-title="Kasei Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 22, 2019</h3>
#  <div class="item_tease_overlay">Kasei Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Kasei Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23565-640x350.jpg" title="Kasei Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 22, 2019</div>
#  <div class="content_title">
#  										  Kasei Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a portion of Kasei Valles. In the region of this image Kasei Valles is flowing northward from Vallis Marineris.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows an interesting sand dune on the floor of an unnamed crater in Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23564_hires.jpg" data-link="/spaceimages/details.php?id=PIA23564" data-thumbnail="/spaceimages/images/wallpaper/PIA23564-640x350.jpg" data-title="Terra Sabaea Dune">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 21, 2019</h3>
#  <div class="item_tease_overlay">Terra Sabaea Dune</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Sabaea Dune" class="thumb" src="/spaceimages/images/wallpaper/PIA23564-640x350.jpg" title="Terra Sabaea Dune"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 21, 2019</div>
#  <div class="content_title">
#  										  Terra Sabaea Dune
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows an interesting sand dune on the floor of an unnamed crater in Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the eastern flank of Alba Mons. Linear faults and graben surround the volcano aligned north/south, intersecting and deflected around the summit." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23563_hires.jpg" data-link="/spaceimages/details.php?id=PIA23563" data-thumbnail="/spaceimages/images/wallpaper/PIA23563-640x350.jpg" data-title="Phlegethon Catena">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 20, 2019</h3>
#  <div class="item_tease_overlay">Phlegethon Catena</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Phlegethon Catena" class="thumb" src="/spaceimages/images/wallpaper/PIA23563-640x350.jpg" title="Phlegethon Catena"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 20, 2019</div>
#  <div class="content_title">
#  										  Phlegethon Catena
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the eastern flank of Alba Mons. Linear faults and graben surround the volcano aligned north/south, intersecting and deflected around the summit.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the region where the northward flow of Kasei Valles turns to the east having split into two large channels." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23562_hires.jpg" data-link="/spaceimages/details.php?id=PIA23562" data-thumbnail="/spaceimages/images/wallpaper/PIA23562-640x350.jpg" data-title="Kasei Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 19, 2019</h3>
#  <div class="item_tease_overlay">Kasei Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Kasei Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23562-640x350.jpg" title="Kasei Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 19, 2019</div>
#  <div class="content_title">
#  										  Kasei Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the region where the northward flow of Kasei Valles turns to the east having split into two large channels.
#  										</div>
#  </div>
#  </div>
#  </a>,
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Shalbatana Vallis. Located in Xanthe Terra, Shalbatana Vallis is one of many channels that empty into Chryse Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23561_hires.jpg" data-link="/spaceimages/details.php?id=PIA23561" data-thumbnail="/spaceimages/images/wallpaper/PIA23561-640x350.jpg" data-title="Shalbatana Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 18, 2019</h3>
#  <div class="item_tease_overlay">Shalbatana Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Shalbatana Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23561-640x350.jpg" title="Shalbatana Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 18, 2019</div>
#  <div class="content_title">
#  										  Shalbatana Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Shalbatana Vallis. Located in Xanthe Terra, Shalbatana Vallis is one of many channels that empty into Chryse Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>]

# %%
# pull image link
feat_img = []
for img in imgs:
    pic = img['data-fancybox-href']
    feat_img.append(pic)

featured_image_url = 'https://www.jpl.nasa.gov' + pic
featured_image_url
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA23561_hires.jpg'

# %%
### Mars Weather

# Visit the Mars Weather twitter account [here](https://twitter.com/marswxreport?lang=en) and scrape the latest Mars 
# weather tweet from the page. Save the tweet text for the weather report as a variable called `mars_weather`.

# %%
# Setting up windows browser with chromedriver
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

url='https://twitter.com/marswxreport?lang=en'
browser.visit(url)
html=browser.html
soup=bs(html,'html.parser')

# %%
mars_weather = soup.find('p',class_='TweetTextSize').text
mars_weather
# Out:
# 'A 4K sweep across the foothills of Mt. Sharp, #Mars, using @MarsCuriosity MastCam imagery.\n\nOn YouTube @ 4k60fps: https://youtu.be/LHLORu8vBmo\xa0\n\nFull Image: https://flic.kr/p/2i3w9PP\xa0pic.twitter.com/lnYE8BO7Nl'

# %%
### Mars Facts
# Visit the Mars Facts webpage [here](https://space-facts.com/mars/) and use Pandas to scrape the table containing 
# facts about the planet including Diameter, Mass, etc.

#Use Pandas to convert the data to a HTML table string.

# %%
url = 'https://space-facts.com/mars/'
response = requests.get(url)
soup = bs(response.text, 'html.parser')

# %%
#Review html format
#print(soup.prettify())

# %%
tables = pd.read_html(url)
tables[0]
# Out:
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
marsdf = tables[0]
marsdf
# Out:
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
marsdf.columns = ['Stat', 'Measurement']
marsdf.head()
# Out:
#                    Stat                    Measurement
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)

# %%
s = pd.Series(marsdf['Stat'])
marsdf['Stat'] = s.str.strip(':')
marsdf
# Out:
#                   Stat                    Measurement
# 0  Equatorial Diameter                       6,792 km
# 1       Polar Diameter                       6,752 km
# 2                 Mass  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons            2 (Phobos & Deimos)
# 4       Orbit Distance       227,943,824 km (1.38 AU)
# 5         Orbit Period           687 days (1.9 years)
# 6  Surface Temperature                   -87 to -5 °C
# 7         First Record              2nd millennium BC
# 8          Recorded By           Egyptian astronomers

# %%
marsdf = marsdf.set_index('Stat')
marsdf
# Out:
#                                        Measurement
# Stat
# Equatorial Diameter                       6,792 km
# Polar Diameter                            6,752 km
# Mass                 6.39 × 10^23 kg (0.11 Earths)
# Moons                          2 (Phobos & Deimos)
# Orbit Distance            227,943,824 km (1.38 AU)
# Orbit Period                  687 days (1.9 years)
# Surface Temperature                   -87 to -5 °C
# First Record                     2nd millennium BC
# Recorded By                   Egyptian astronomers

# %%
#Use to_html method to generate HTML tables from df
html_table = marsdf.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Measurement</th>\n    </tr>\n    <tr>\n      <th>Stat</th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Equatorial Diameter</th>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>Polar Diameter</th>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>Mass</th>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <th>Moons</th>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>Orbit Distance</th>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <th>Orbit Period</th>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>Surface Temperature</th>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>First Record</th>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <th>Recorded By</th>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %%
#Save as html file
marsdf.to_html('mars_table.html')

# %%
### Mars Hemispheres
# Visit the USGS Astrogeology site [here]
# (https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars) to obtain high resolution 
# images for each of Mar's hemispheres.

# You will need to click each of the links to the hemispheres in order to find the image url to the full resolution image.

# Save both the image url string for the full resolution hemisphere image, and the Hemisphere title containing the 
# hemisphere name. Use a Python dictionary to store the data using the keys `img_url` and `title`.

# Append the dictionary with the image url string and the hemisphere title to a list. This list will contain one 
# dictionary for each hemisphere.

# Example:
#hemisphere_image_urls = [
#    {"title": "Valles Marineris Hemisphere", "img_url": "..."},
#    {"title": "Cerberus Hemisphere", "img_url": "..."},
#    {"title": "Schiaparelli Hemisphere", "img_url": "..."},
#    {"title": "Syrtis Major Hemisphere", "img_url": "..."},
#]

# %%
# Setting up windows browser with chromedriver
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Setting url for alternate browser
url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(url)

# %%
nextpage_urls = []
imgtitles = []
base_url = 'https://astrogeology.usgs.gov'

# HTML object
html = browser.html
# Parse HTML with Beautiful Soup
soup = bs(html, 'html.parser')
# Retrieve all elements that contain hemisphere photo info
divs = soup.find_all('div', class_='description')

# Iterate through each div to pull titles and make list of hrefs to iterate through
counter = 0
for div in divs:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
    link = div.find('a')
    href=link['href']
    img_title = div.a.find('h3')
    img_title = img_title.text
    imgtitles.append(img_title)
    next_page = base_url + href
    nextpage_urls.append(next_page)
    counter = counter+1
    if (counter == 4):
        break
print(nextpage_urls)
print(imgtitles)
# Out:
# ['https://astrogeology.usgs.gov/search/map/Mars/Viking/cerberus_enhanced', 'https://astrogeology.usgs.gov/search/map/Mars/Viking/schiaparelli_enhanced', 'https://astrogeology.usgs.gov/search/map/Mars/Viking/syrtis_major_enhanced', 'https://astrogeology.usgs.gov/search/map/Mars/Viking/valles_marineris_enhanced']
# ['Cerberus Hemisphere Enhanced', 'Schiaparelli Hemisphere Enhanced', 'Syrtis Major Hemisphere Enhanced', 'Valles Marineris Hemisphere Enhanced']

# %%
# Creating loop for high resolution photo on next page

my_images=[]
for nextpage_url in nextpage_urls:
    url = nextpage_url
    browser.visit(url)
    html = browser.html
    soup = bs(html, 'html.parser')
    link2 = soup.find('img', class_="wide-image")
    forfinal = link2['src']
    full_img = base_url + forfinal
    my_images.append(full_img)
    nextpage_urls = []
my_images
# Out:
# ['https://astrogeology.usgs.gov/cache/images/cfa62af2557222a02478f1fcd781d445_cerberus_enhanced.tif_full.jpg',
#  'https://astrogeology.usgs.gov/cache/images/3cdd1cbf5e0813bba925c9030d13b62e_schiaparelli_enhanced.tif_full.jpg',
#  'https://astrogeology.usgs.gov/cache/images/ae209b4e408bb6c3e67b6af38168cf28_syrtis_major_enhanced.tif_full.jpg',
#  'https://astrogeology.usgs.gov/cache/images/7cf2da4bf549ed01c17f206327be4db7_valles_marineris_enhanced.tif_full.jpg']

# %%
# Creating final list of dictionaries
# values - imgtitles and my_images
#ckeys- img_url and title
hemisphere_image_urls = []

cerberus = {'title':imgtitles[0], 'img_url': my_images[0]}
schiaparelli = {'title':imgtitles[1], 'img_url': my_images[1]}
syrtis = {'title':imgtitles[2], 'img_url': my_images[2]}
valles = {'title':imgtitles[3], 'img_url': my_images[3]}

hemisphere_image_urls = [cerberus, schiaparelli, syrtis, valles]
print(hemisphere_image_urls)
# Out:
# [{'title': 'Cerberus Hemisphere Enhanced', 'img_url': 'https://astrogeology.usgs.gov/cache/images/cfa62af2557222a02478f1fcd781d445_cerberus_enhanced.tif_full.jpg'}, {'title': 'Schiaparelli Hemisphere Enhanced', 'img_url': 'https://astrogeology.usgs.gov/cache/images/3cdd1cbf5e0813bba925c9030d13b62e_schiaparelli_enhanced.tif_full.jpg'}, {'title': 'Syrtis Major Hemisphere Enhanced', 'img_url': 'https://astrogeology.usgs.gov/cache/images/ae209b4e408bb6c3e67b6af38168cf28_syrtis_major_enhanced.tif_full.jpg'}, {'title': 'Valles Marineris Hemisphere Enhanced', 'img_url': 'https://astrogeology.usgs.gov/cache/images/7cf2da4bf549ed01c17f206327be4db7_valles_marineris_enhanced.tif_full.jpg'}]

# %% [markdown]
# ### end of the assigment_Elvis Selimaj
